# %% [markdown]
# # Guitar notes, scales

# %% [markdown]
# <img src="https://www.ginoguitars.com/images/products/Gibson-USA-Les-Paul-Standard-2016-T-368-LB_01.jpg" width=360>

# %% [markdown]
# ## 1. Guitar notes & scales

# %% [markdown]
# A scale in music is constructed from a series of tones. The amount varies, major and minor scales, for example, contains seven tones of twelve possible semi-tones. Such series of tones will sound great played together and are often used as foundation for composing or improvisation. They can be played in any order – playing them root to root is only when practicing.
#
# The most common modes in music are **Ionian, Dorian, Phrygian, Lydian, Mixolydian, Aeolian and Locrian**. These goes back to the Ancient Greece and are still used in music today

# %% [markdown]
# > Credits: https://betterprogramming.pub/how-to-learn-guitar-with-python-978a1896a47

# %%
import datetime
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import numpy as np
import sys
import IPython.display as display

# %%
sys.version
# Out:
# '3.8.5 (default, Sep  4 2020, 07:30:14) \n[GCC 7.3.0]'

# %%
print('Today is: ' + str(datetime.datetime.today()))
# Out:
# Today is: 2023-02-21 09:06:26.231292

# %%
images_dir = "scales"

os.makedirs(images_dir, exist_ok=True)

# %% [markdown]
# ### 1 Guitar notes

# %%
all_notes = ['C', 'C#', 'D', 'D#', 'E', 'F', 'F#', 'G', 'G#', 'A', 'A#', 'B'
             ] * 3

# %%
print(all_notes)
# Out:
# ['C', 'C#', 'D', 'D#', 'E', 'F', 'F#', 'G', 'G#', 'A', 'A#', 'B', 'C', 'C#', 'D', 'D#', 'E', 'F', 'F#', 'G', 'G#', 'A', 'A#', 'B', 'C', 'C#', 'D', 'D#', 'E', 'F', 'F#', 'G', 'G#', 'A', 'A#', 'B']

# %%
note = 'A'

start = all_notes.index(note)
notes_list = all_notes[start:start + 12]
print(note, 'Chromatic scale =', notes_list)
# Out:
# A Chromatic scale = ['A', 'A#', 'B', 'C', 'C#', 'D', 'D#', 'E', 'F', 'F#', 'G', 'G#']

# %% [markdown]
# ### 1.1 Guitar scales

# %%
scales = {
    "aeolian": [
        0,
        2,
        3,
        5,
        7,
        8,
        10,
    ],
    "dorian": [0, 2, 3, 5, 7, 9, 10],
    "harmonic minor": [0, 2, 3, 5, 7, 8, 11],
    "locrian": [
        0,
        1,
        3,
        5,
        6,
        8,
        10,
    ],
    "lydian": [
        0,
        2,
        4,
        6,
        7,
        9,
        11,
    ],
    "major": [0, 2, 4, 5, 7, 9, 11],
    "major pentatonic": [0, 2, 4, 7, 9],
    "minor": [
        0,
        2,
        3,
        5,
        7,
        8,
        10,
    ],
    "minor blues": [0, 3, 5, 6, 7, 10],
    "minor pentatonic": [0, 3, 5, 7, 10],
    "phrygian": [0, 1, 3, 5, 7, 8, 10],
}

# %%
scales
# Out:
# {'aeolian': [0, 2, 3, 5, 7, 8, 10],
#  'dorian': [0, 2, 3, 5, 7, 9, 10],
#  'harmonic minor': [0, 2, 3, 5, 7, 8, 11],
#  'locrian': [0, 1, 3, 5, 6, 8, 10],
#  'lydian': [0, 2, 4, 6, 7, 9, 11],
#  'major': [0, 2, 4, 5, 7, 9, 11],
#  'major pentatonic': [0, 2, 4, 7, 9],
#  'minor': [0, 2, 3, 5, 7, 8, 10],
#  'minor blues': [0, 3, 5, 6, 7, 10],
#  'minor pentatonic': [0, 3, 5, 7, 10],
#  'phrygian': [0, 1, 3, 5, 7, 8, 10]}

# %%
scales['phrygian']
# Out:
# [0, 1, 3, 5, 7, 8, 10]

# %% [markdown]
# ### 1.2 Some Python functions

# %%
def get_notes_key_internal(key, interval):
    """
    Get notes from a key and interval
    """
    start = all_notes.index(key)
    octave = all_notes[start:start + 12]
    result = [octave[idx] for idx in interval]

    return result

# %%
def get_notes(note, scale):
    """
    Get notes from a scale
    """
    print("Notes of", note, "for scale", scale, "=",
          get_notes_key_internal(note, scales[scale]))

# %%
def finding_notes(scale):
    """
    Finding guitar notes from a scale
    """
    notes_strings = {idx: 0 for idx in "EADGBE"}

    for key in strings.keys():
        indexes = []

        for note in scale:
            idx = strings[key].index(note)
            indexes.append(idx)

            if idx <= 7:
                indexes.append(idx + 12)

        notes_strings[key] = indexes

    return notes_strings

# %%
def guitar_scale_view(notemode, mode):
    """
    View notes on a guitar fretboard
    """
    scalemode = scales[mode]
    scale = get_notes_key_internal(notemode, scalemode)

    fig, ax = plt.subplots(figsize=(18, 5))

    for idx in range(1, 7):
        ax.plot([idx for a in range(23)])

    ax.set_axisbelow(True)
    ax.set_xlim([0, 21])
    ax.set_ylim([0.5, 6.5])
    ax.set_facecolor("#654321")  # Brown color
    guitar_plot = finding_notes(scale)

    for y, key in zip([1, 2, 3, 4, 5, 6],
                      'EADGBE'):  # common 6 strings guitar tuning
        for idx in guitar_plot[key]:
            x = idx + 0.5
            p = mpatches.Circle((x, y), 0.3)
            ax.add_patch(p)
            note = strings[key][idx]
            ax.annotate(note, (idx + 0.5, y),
                        color='white',
                        weight='bold',
                        fontsize=12,
                        ha='center',
                        va='center')

    plt.yticks(np.arange(1, 7), ['E', 'A', 'D', 'G', 'B', 'E'])
    plt.xticks(np.arange(21) + 0.5, np.arange(0, 21))
    ax.grid(True)
    plt.title(notemode + " " + mode + " scales", size=15)
    plt.xlabel('Guitar fretboard', size=12)
    plt.ylabel('Guitar strings', size=12)
    plt.savefig(images_dir + "/" + notemode + "_" + mode + "_scale.jpg",
                dpi=300)

    plt.show()

# %% [markdown]
# ### 1.3 Getting some notes

# %%
get_notes('C', "major")
# Out:
# Notes of C for scale major = ['C', 'D', 'E', 'F', 'G', 'A', 'B']

# %%
get_notes('F#', "major pentatonic")
# Out:
# Notes of F# for scale major pentatonic = ['F#', 'G#', 'A#', 'C#', 'D#']

# %%
get_notes('C', "harmonic minor")
# Out:
# Notes of C for scale harmonic minor = ['C', 'D', 'D#', 'F', 'G', 'G#', 'B']

# %% [markdown]
# ### 1.4 All notes from a guitar

# %%
nb_string = 1

strings = []
strings = {idx: 0 for idx in "EADGBE"}

for idx in strings.keys():
    start = all_notes.index(idx)
    strings[idx] = all_notes[start:start + 20]

for idx in "EADGBE":  # Standard tuning is EADGBE
    print(nb_string, idx, 'string notes:\n', strings[idx])
    print()
    nb_string += 1
# Out:
# 1 E string notes:
#  ['E', 'F', 'F#', 'G', 'G#', 'A', 'A#', 'B', 'C', 'C#', 'D', 'D#', 'E', 'F', 'F#', 'G', 'G#', 'A', 'A#', 'B']
#
# 2 A string notes:
#  ['A', 'A#', 'B', 'C', 'C#', 'D', 'D#', 'E', 'F', 'F#', 'G', 'G#', 'A', 'A#', 'B', 'C', 'C#', 'D', 'D#', 'E']
#
# 3 D string notes:
#  ['D', 'D#', 'E', 'F', 'F#', 'G', 'G#', 'A', 'A#', 'B', 'C', 'C#', 'D', 'D#', 'E', 'F', 'F#', 'G', 'G#', 'A']
#
# 4 G string notes:
#  ['G', 'G#', 'A', 'A#', 'B', 'C', 'C#', 'D', 'D#', 'E', 'F', 'F#', 'G', 'G#', 'A', 'A#', 'B', 'C', 'C#', 'D']
#
# 5 B string notes:
#  ['B', 'C', 'C#', 'D', 'D#', 'E', 'F', 'F#', 'G', 'G#', 'A', 'A#', 'B', 'C', 'C#', 'D', 'D#', 'E', 'F', 'F#']
#
# 6 E string notes:
#  ['E', 'F', 'F#', 'G', 'G#', 'A', 'A#', 'B', 'C', 'C#', 'D', 'D#', 'E', 'F', 'F#', 'G', 'G#', 'A', 'A#', 'B']

# %% [markdown]
# <img src="https://miro.medium.com/max/720/1*-ULyT6axpA-DiJWSWhBq1w.webp">

# %% [markdown]
# ### 1.5 Now we can view the scales notes on a guitar fretboard

# %%
scales
# Out:
# {'aeolian': [0, 2, 3, 5, 7, 8, 10],
#  'dorian': [0, 2, 3, 5, 7, 9, 10],
#  'harmonic minor': [0, 2, 3, 5, 7, 8, 11],
#  'locrian': [0, 1, 3, 5, 6, 8, 10],
#  'lydian': [0, 2, 4, 6, 7, 9, 11],
#  'major': [0, 2, 4, 5, 7, 9, 11],
#  'major pentatonic': [0, 2, 4, 7, 9],
#  'minor': [0, 2, 3, 5, 7, 8, 10],
#  'minor blues': [0, 3, 5, 6, 7, 10],
#  'minor pentatonic': [0, 3, 5, 7, 10],
#  'phrygian': [0, 1, 3, 5, 7, 8, 10]}

# %%
guitar_scale_view('C', 'aeolian')

# %%
guitar_scale_view('E', 'dorian')

# %%
guitar_scale_view('A#', 'major pentatonic')

# %%
os.listdir(images_dir)
# Out:
# ['A#_major pentatonic_scale.jpg', 'C_aeolian_scale.jpg', 'E_dorian_scale.jpg']
